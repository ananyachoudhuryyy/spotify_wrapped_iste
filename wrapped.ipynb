# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler
import pickle

# %%
def load_data():   
     df=pd.read_csv(r"D:\codes\Datasets\Liked_Songs.csv")
     return df

# %%
FEATURES = [
    'Danceability',
    'Energy',
    'Loudness',
    'Speechiness',
    'Acousticness',
    'Instrumentalness',
    'Liveness',
    'Valence',
    'Tempo'
]

def select_features (df):
    return df[FEATURES]

# %%
def clean_data(df):
    return df

# %%
def assign_mood(row):
    try:
        if pd.isna(row['Valence']) or pd.isna(row['Energy']) or pd.isna(row['Acousticness']) or pd.isna(row['Tempo']):
            return 'Sad'  # Default mood if any required value is missing
            
        if float(row['Valence']) > 0.6 and float(row['Energy']) > 0.6:
            return 'Happy'
        elif float(row['Energy']) < 0.4 and float(row['Acousticness']) > 0.5:
            return 'Chill'
        elif float(row['Energy']) > 0.7 and float(row['Tempo']) > 120:
            return 'Energetic'
        else:
            return 'Sad'
    except Exception as e:
        print(f"Error processing row: {e}")
        return 'Sad'  # Default mood on error

def create_mood_labels(df):
    # Make a copy to avoid SettingWithCopyWarning
    df = df.copy()
    # Create mood column by applying the function to each row
    df.loc[:, 'Mood'] = df.apply(lambda row: assign_mood(row), axis=1)
    print(df)
    return df

# %%
def prepare_data():
    try:
        # Load and clean data
        df = load_data()
        if df.empty:
            raise ValueError("Loaded DataFrame is empty")
        
        # Create mood labels
        df = create_mood_labels(df)
        # Select features and target
        X = select_features(df).copy()
        y = df["Mood"].copy()
        
        # Ensure we have data to work with
        if len(X) == 0 or len(y) == 0:
            raise ValueError("No data available after processing")
            
        return X, y
        
    except Exception as e:
        print(f"Error in prepare_data: {str(e)}")
        # Print debug information
        if 'df' in locals():
            print("\nDataFrame info:")
            print(df.info())
            print("\nFirst few rows:")
            print(df.head())
        raise

# %%
def split_data(X, y):
    return train_test_split(
        X,
        y,
        test_size=0.4,
        random_state=69,
        stratify=y
    )

# %%
def feature_scaling(X_train, X_test):
    scaler = StandardScaler()

    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    return X_train_scaled, X_test_scaled, scaler

# %%
def train_model(X_train, y_train):
    model = LogisticRegression(max_iter = 1000)
    model.fit(X_train, y_train)
    return model

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)

    print("\nAccuracy:", accuracy_score(y_test, y_pred))
    print("\nClassification Report:\n")
    print(classification_report(y_test, y_pred))

# %%
def save_model(model, scaler):
    with open("model.pkl", "wb") as f:
        pickle.dump(model, f)

    with open("scaler.pkl", "wb") as f:
        pickle.dump(scaler, f)

# %%
df = pd.read_csv(r"D:\codes\Datasets\Liked_Songs.csv")
X = df[FEATURES]
X, y = prepare_data()

X_train, X_test, y_train, y_test = split_data(X, y)
X_train_scaled, X_test_scaled, scaler = feature_scaling(X_train, X_test)

model = train_model(X_train_scaled, y_train)
evaluate_model(model, X_test_scaled, y_test)

save_model(model, scaler)
# Out:
#                                  Track URI  \
# 0     spotify:track:4IvZLDtwBHmBmwgDIUbuwa
# 1     spotify:track:5ihS6UUlyQAfmp48eSkxuQ
# 2     spotify:track:0qRR9d89hIS0MHRkQ0ejxX
# 3     spotify:track:52ksVOpMCbimktgmI59GSq
# 4     spotify:track:5Ts1DYOuouQLgzTaisxWYh
# ...                                    ...
# 996   spotify:track:2Q0Y74LoaxFtiyhmdDTZx4
# 997   spotify:track:0kDYa8nqIIpsAZ8FctJyGQ
# 998   spotify:track:1WlBQvMbthidfyEjS2rF16
# 999   spotify:track:6NG2IIXZfC5Notpz0GIODU
# 1000  spotify:track:4Dlxu4QnKM2Z94qLlfEl2N
#
#                                              Track Name  \
# 0                                   Here Comes Your Man
# 1                                             Landslide
# 2                                             Rich Girl
# 3     While My Guitar Gently Weeps - Live from Madis...
# 4                   Love Grows (Where My Rosemary Goes)
# ...                                                 ...
# 996                                      Cotton Eye Joe
# 997                               ...Baby One More Time
# 998                                     Mysterious Girl
# 999        The Ketchup Song (Aserejé) - Spanish Version
# 1000        Cecilia You're Breaking My Heart - Acoustic
#
#                                             Album Name  \
# 0                                            Doolittle
# 1                                        Fleetwood Mac
# 2                               Bigger Than Both Of Us
# 3               Let It Roll - Songs of George Harrison
# 4     Love Grows (Where My Rosemary Goes) & Other Gems
# ...                                                ...
# 996                                       90s 100 Hits
# 997                                       90s 100 Hits
# 998                                   Smash Hits No.1s
# 999                         Aserejé (The Ketchup Song)
# 1000                                 Unplugged Visions
#
#                Artist Name(s) Release Date  Duration (ms)  Popularity  \
# 0                      Pixies   1989-04-17         201186          74
# 1               Fleetwood Mac   1975-07-11         199493          87
# 2     Daryl Hall & John Oates   1976-08-01         142786          78
# 3             George Harrison   2009-01-01         286733          55
# 4           Edison Lighthouse   1970-01-01         174760          74
# ...                       ...          ...            ...         ...
# 996                    Rednex   2014-11-28         193826          29
# 997            Britney Spears   2014-11-28         211066          39
# 998               Peter Andre   2020-07-17         231266           0
# 999               Las Ketchup         2002         213000          65
# 1000                Red Tracy   2015-02-20         156900          13
#
#       Explicit  Added By              Added At  ... Loudness Mode  \
# 0        False       NaN  2026-01-15T04:38:19Z  ...  -10.865    1
# 1        False       NaN  2026-01-15T04:38:07Z  ...  -22.320    0
# 2        False       NaN  2026-01-11T13:21:54Z  ...   -6.644    1
# 3        False       NaN  2026-01-09T13:49:55Z  ...   -6.552    1
# 4        False       NaN  2026-01-05T03:48:42Z  ...   -4.613    1
# ...        ...       ...                   ...  ...      ...  ...
# 996      False       NaN  2023-04-23T06:31:28Z  ...   -7.788    0
# 997      False       NaN  2023-04-23T06:31:00Z  ...   -7.727    0
# 998      False       NaN  2023-04-23T06:06:39Z  ...   -8.779    0
# 999      False       NaN  2023-04-23T05:58:17Z  ...   -5.642    1
# 1000     False       NaN  2023-04-23T05:58:01Z  ...  -11.462    1
#
#       Speechiness  Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# 0          0.0285       0.00772          0.078100    0.4010    0.882  124.594
# 1          0.0318       0.88300          0.000223    0.1170    0.423  159.375
# 2          0.1760       0.46100          0.000000    0.0935    0.817  169.519
# 3          0.0292       0.00341          0.010200    0.7420    0.686  134.245
# 4          0.0299       0.40300          0.000000    0.0855    0.753  108.625
# ...           ...           ...               ...       ...      ...      ...
# 996        0.0668       0.01240          0.002170    0.0338    0.613  131.995
# 997        0.0306       0.19700          0.000313    0.4490    0.912   92.966
# 998        0.2210       0.04780          0.000001    0.0424    0.878  172.052
# 999        0.1150       0.00842          0.000064    0.1230    0.883  184.976
# 1000       0.0356       0.40100          0.000000    0.0535    0.972  100.005
#
#       Time Signature   Mood
# 0                  4  Happy
# 1                  4  Chill
# 2                  4  Happy
# 3                  4  Happy
# 4                  4  Happy
# ...              ...    ...
# 996                4  Happy
# 997                4  Happy
# 998                4  Happy
# 999                4  Happy
# 1000               4    Sad
#
# [1001 rows x 25 columns]
#       Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0            0.669   0.795   -10.865       0.0285       0.00772
# 1            0.414   0.161   -22.320       0.0318       0.88300
# 2            0.573   0.683    -6.644       0.1760       0.46100
# 3            0.349   0.841    -6.552       0.0292       0.00341
# 4            0.568   0.824    -4.613       0.0299       0.40300
# ...            ...     ...       ...          ...           ...
# 996          0.738   0.937    -7.788       0.0668       0.01240
# 997          0.759   0.649    -7.727       0.0306       0.19700
# 998          0.655   0.644    -8.779       0.2210       0.04780
# 999          0.602   0.947    -5.642       0.1150       0.00842
# 1000         0.809   0.481   -11.462       0.0356       0.40100
#
#       Instrumentalness  Liveness  Valence    Tempo
# 0             0.078100    0.4010    0.882  124.594
# 1             0.000223    0.1170    0.423  159.375
# 2             0.000000    0.0935    0.817  169.519
# 3             0.010200    0.7420    0.686  134.245
# 4             0.000000    0.0855    0.753  108.625
# ...                ...       ...      ...      ...
# 996           0.002170    0.0338    0.613  131.995
# 997           0.000313    0.4490    0.912   92.966
# 998           0.000001    0.0424    0.878  172.052
# 999           0.000064    0.1230    0.883  184.976
# 1000          0.000000    0.0535    0.972  100.005
#
# [1001 rows x 9 columns]
#
# 0       Happy
# 1       Chill
# 2       Happy
# 3       Happy
# 4       Happy
#         ...
# 996     Happy
# 997     Happy
# 998     Happy
# 999     Happy
# 1000      Sad
# Name: Mood, Length: 1001, dtype: object
#
# Accuracy: 0.830423940149626
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#        Chill       0.84      0.67      0.74        24
#    Energetic       0.66      0.49      0.56        43
#        Happy       0.89      0.93      0.91       165
#          Sad       0.80      0.85      0.82       169
#
#     accuracy                           0.83       401
#    macro avg       0.80      0.73      0.76       401
# weighted avg       0.83      0.83      0.83       401
